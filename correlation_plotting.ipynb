# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50.9.model_sensitivities.npy')
cor = np.corrcoef(sensitivities,rowvar=0)
tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(cor, cmap=cmap, xticklabels=tick, yticklabels=tick, square=True, cbar=False)
plt.savefig('../model/CONLL003/lstmtestglove50.9.model_sensitivities_correlation.png', bbox_inches = 'tight')

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50_1.9.model_sensitivities.npy')
cor = np.corrcoef(sensitivities,rowvar=0)
tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(cor, cmap=cmap, xticklabels=tick, yticklabels=tick, square=True, cbar=False)
plt.savefig('../model/CONLL003/lstmtestglove50_1.9.model_sensitivities_correlation.png', bbox_inches = 'tight')

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50_2.9.model_sensitivities.npy')
cor = np.corrcoef(sensitivities,rowvar=0)
tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(cor, cmap=cmap, xticklabels=tick, yticklabels=tick, square=True, cbar=False)
plt.savefig('../model/CONLL003/lstmtestglove50_2.9.model_sensitivities_correlation.png', bbox_inches = 'tight')

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50_3.9.model_sensitivities.npy')
cor = np.corrcoef(sensitivities,rowvar=0)
tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(cor, cmap=cmap, xticklabels=tick, yticklabels=tick, square=True, cbar=False)
plt.savefig('../model/CONLL003/lstmtestglove50_3.9.model_sensitivities_correlation.png', bbox_inches = 'tight')

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50_4.10.model_sensitivities.npy')
cor = np.corrcoef(sensitivities,rowvar=0)
tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(cor, cmap=cmap, xticklabels=tick, yticklabels=tick, square=True, cbar=False)
plt.savefig('../model/CONLL003/lstmtestglove50_4.10.model_sensitivities_correlation.png', bbox_inches = 'tight')

# %%
sensitivities = np.load('../model/CONLL003/lstmtestglove50.9.model_sensitivities.npy')
# sens_abs = np.abs(sensitivities)
sum_sens = np.sum(sensitivities, axis=1)
index = sum_sens.argsort()[::-1][0:10]

# %%
sorted(index)
# Out:
# [4, 11, 20, 22, 23, 28, 34, 39, 44, 48]

# %%
plt.figure(figsize=(10, 5))
x_tick = ['B-PER', 'I-PER', 'B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-MISC', 'I-MISC', 'O']
cmap = sns.diverging_palette(260, 10, as_cmap=True)
ax = sns.heatmap(sensitivities[sorted(index)], xticklabels=x_tick, yticklabels=sorted(index), annot=True, fmt=".2g", cmap=cmap)
ax.xaxis.set_ticks_position('top')
# plt.title(title, fontsize=18)
plt.xticks(rotation=360)
plt.yticks(rotation=360)
plt.show()
ax.figure.savefig("../model/CONLL003/lstmtestglove50.9.model_sensitivities_heatmap.png", bbox_inches = 'tight')
